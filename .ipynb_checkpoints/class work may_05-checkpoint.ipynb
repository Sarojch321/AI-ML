# %%
import pandas as pd

# %%
data = pd.read_csv("Bankloan.txt")
data.head()
# Out:
#     age   ed  employ  address  income  debtinc   creddebt   othdebt default
# 0  41.0  3.0      17       12   176.0      9.3  11.359392  5.008608       1
# 1  27.0  1.0      10        6    31.0     17.3   1.362202  4.000798       0
# 2  40.0  1.0      15        7     NaN      5.5   0.856075  2.168925       0
# 3  41.0  NaN      15       14   120.0      2.9   2.658720  0.821280       0
# 4  24.0  2.0       2        0    28.0     17.3   1.787436  3.056564       1

# %%
data.isnull().sum()
# Out:
# age         19
# ed          20
# employ       0
# address      0
# income      37
# debtinc      0
# creddebt     0
# othdebt      0
# default      0
# dtype: int64

# %%
data[data.isnull().any(axis = 1)]
# Out:
#       age   ed  employ  address  income  debtinc  creddebt    othdebt default
# 2    40.0  1.0      15        7     NaN      5.5  0.856075   2.168925       0
# 3    41.0  NaN      15       14   120.0      2.9  2.658720   0.821280       0
# 6    39.0  1.0      20        9     NaN     30.6  3.833874  16.668126       0
# 7     NaN  1.0      12       11    38.0      3.6  0.128592   1.239408       0
# 19    NaN  NaN       0       21    26.0      1.7  0.099008   0.342992       0
# ..    ...  ...     ...      ...     ...      ...       ...        ...     ...
# 620  25.0  1.0       1        1     NaN      6.9  0.190095   1.120905       0
# 624  29.0  1.0       6        4     NaN      5.4  1.169964   1.314036       0
# 672  34.0  1.0       6        1     NaN      1.2  0.042480   0.197520       0
# 692   NaN  1.0       0       26     NaN     28.9  2.754459   5.048541       1
# 699  37.0  1.0      12       14     NaN     14.7  2.994684   3.473316       0
#
# [74 rows x 9 columns]

# %%
data['age'] = data['age'].fillna(data['age'].mean())
data['ed'] = data['ed'].fillna(data['ed'].mean())
data['income'] = data['income'].fillna(data['income'].mean())

# %%
data[data.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [age, ed, employ, address, income, debtinc, creddebt, othdebt, default]
# Index: []

# %%
x = data.drop("default", axis = 1)
y = data.default

# %%
y = pd.to_numeric(y, errors='coerce')
y = y.dropna()
x = x.loc[y.index]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = 0.2, random_state = 3)

# %%
logmodel = LogisticRegression()
logmodel.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred = logmodel.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy = accuracy_score(ytest, ypred)
print("Accuracy :", accuracy)
# Out:
# Accuracy : 0.7642857142857142

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
ypred = decision_tree.predict(xtest)
ypred_train = decision_tree.predict(xtrain)

# %%
accuracy = accuracy_score(ytest, ypred)
print("Test Accuracy :", accuracy)
accuracy = accuracy_score(ytrain, ypred_train)      # Overfitting
print("Train Accuracy :", accuracy)
# Out:
# Test Accuracy : 0.7714285714285715
# Train Accuracy : 0.8745519713261649

# %%
decision_tree = DecisionTreeClassifier(max_depth = 5)
decision_tree.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
ypred = decision_tree.predict(xtest)
ypred_train = decision_tree.predict(xtrain)
accuracy = accuracy_score(ytest, ypred)
print("Test Accuracy :", accuracy)
accuracy = accuracy_score(ytrain, ypred_train)
print("Train Accuracy :", accuracy)
# Out:
# Test Accuracy : 0.7714285714285715
# Train Accuracy : 0.8745519713261649

# %% [markdown]
# ### Neural Network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(xtrain)
x_test_scaled = scaler.transform(xtest)

# %%
model = Sequential([
    Dense(32, input_dim = 8, activation = 'relu'),
    Dense(16, activation = 'relu'),
    Dense(8, activation = 'relu'),
    Dense(4, activation = 'relu'),
    Dense(1, activation = "sigmoid")
])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'sgd', loss = 'binary_crossentropy', metrics =['accuracy'])

# %%
trains = model.fit(x_train_scaled, ytrain, epochs = 80)
# Out:
# Epoch 1/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4521 - loss: 0.6990
# Epoch 2/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6485 - loss: 0.6865
# Epoch 3/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7359 - loss: 0.6724
# Epoch 4/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7461 - loss: 0.6618
# Epoch 5/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7618 - loss: 0.6507
# Epoch 6/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7466 - loss: 0.6430
# Epoch 7/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7458 - loss: 0.6348
# Epoch 8/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7328 - loss: 0.6295
# Epoch 9/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7684 - loss: 0.6087
# Epoch 10/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7386 - loss: 0.6103
# Epoch 11/80
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7321 - loss: 0.6058
# Epoch 12/80
# ...

# %%
test_loss = model.evaluate(x_test_scaled, ytest)
print(test_loss)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7773 - loss: 0.4410
# [0.43300220370292664, 0.7785714268684387]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(trains.history['accuracy'])
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.show()

# %%
plt.plot(trains.history['loss'])
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.show()
